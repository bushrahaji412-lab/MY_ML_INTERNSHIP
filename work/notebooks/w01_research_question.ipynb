# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bushrahaji412-lab/MY_ML_INTERNSHIP/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# # My Lane
#
# I selected the SEO Content Optimization lane because it focuses on identifying which web pages have the greatest potential for improving search performance. This project can help prioritize pages that are more likely to benefit from optimization. I chose this lane because it connects data with a real business decision and provides an opportunity to learn how machine learning can support decision-making.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## Decision
#
# The decision is to identify which pages should receive SEO improvements first.
#
# ## Action
#
# The SEO team can focus their time and resources on optimizing the selected pages.
#
# ## Cost of a Wrong Recommendation
#
# If the recommendation is incorrect, time and resources may be wasted on pages that do not improve performance, while important pages may be ignored.
#
# ## Why Data or Machine Learning Can Help
#
# The dataset contains many pages and multiple features. Machine learning can identify useful patterns and support better decision-making.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
print("Average CTR:", round(df["ctr"].mean(), 4))
print("Average Search Volume:", round(df["search_volume"].mean(), 2))
print("Average Impressions:", round(df["impressions_90d"].mean(), 2))
# Out:
# Average CTR: 0.5107
# Average Search Volume: 158.88
# Average Impressions: 5200.37

# %%
# !find . -name "*.csv"
# Out:
# ./data/raw/content_refresh_anonymized.csv
# ./outputs/refresh_queue_sample.csv

# %%
# !git clone https://github.com/bushrahaji412-lab/MY_ML_INTERNSHIP.git
# Out:
# Cloning into 'MY_ML_INTERNSHIP'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 115 (delta 32), reused 87 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (115/115), 1.82 MiB | 9.53 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# %cd MY_ML_INTERNSHIP
# Out:
# /content/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(df.head())
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
# !pwd
# !ls
# !find /content -name "*.csv"
# Out:
# /content/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission
# /content/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/data/raw/content_refresh_anonymized.csv
# /content/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/outputs/refresh_queue_sample.csv
# /content/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/data/raw/content_refresh_anonymized.csv
# /content/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/outputs/refresh_queue_sample.csv
# ...

# %%
# %cd MY_ML_INTERNSHIP
# Out:
# [Errno 2] No such file or directory: 'MY_ML_INTERNSHIP'
# /content/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP/MY_ML_INTERNSHIP

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

df.head()
# Out:
# Rows: 30000
# Columns: 44
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words
#
# This project identifies patterns in the available dataset. The analysis does not prove cause and effect, and any recommendations should be validated before making business decisions. The results depend on the quality and scope of the available data.

# %%
print("Careful words section completed.")
# Out:
# Careful words section completed.

# %% [markdown]
# ## Careful Words
#
# This project identifies patterns in the available dataset. The analysis does not prove cause and effect, and any recommendations should be validated before making business decisions. The results depend on the quality and scope of the available data.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
